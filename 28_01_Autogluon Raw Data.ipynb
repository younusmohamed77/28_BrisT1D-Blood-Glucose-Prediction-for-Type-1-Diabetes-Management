# %% [markdown]
# #### BrisT1D Blood Glucose Prediction Competition
# Using historical blood glucose readings, insulin dosage, carbohydrate intake, and smartwatch activity data to predict future blood glucose
#
# Kaggle - https://www.kaggle.com/competitions/brist1d.

# %%
import pandas as pd
from autogluon.tabular import TabularDataset, TabularPredictor

# %%
# Load datasets
train_data = TabularDataset('train.csv')
test_data = TabularDataset('test.csv')

# %%
train_data.head()
# Out:
#       id p_num      time  bg-5:55  bg-5:50  bg-5:45  bg-5:40  bg-5:35  \
# 0  p01_0   p01  06:10:00      NaN      NaN      9.6      NaN      NaN
# 1  p01_1   p01  06:25:00      NaN      NaN      9.7      NaN      NaN
# 2  p01_2   p01  06:40:00      NaN      NaN      9.2      NaN      NaN
# 3  p01_3   p01  06:55:00      NaN      NaN      8.7      NaN      NaN
# 4  p01_4   p01  07:10:00      NaN      NaN      8.4      NaN      NaN
#
#    bg-5:30  bg-5:25  ...  activity-0:40  activity-0:35  activity-0:30  \
# 0      9.7      NaN  ...            NaN            NaN            NaN
# 1      9.2      NaN  ...            NaN            NaN            NaN
# 2      8.7      NaN  ...            NaN            NaN            NaN
# 3      8.4      NaN  ...            NaN            NaN            NaN
# 4      8.1      NaN  ...            NaN            NaN            NaN
#
#    activity-0:25  activity-0:20  activity-0:15  activity-0:10  activity-0:05  \
# 0            NaN            NaN            NaN            NaN            NaN
# 1            NaN            NaN            NaN            NaN            NaN
# 2            NaN            NaN            NaN            NaN            NaN
# 3            NaN            NaN            NaN            NaN            NaN
# 4            NaN            NaN            NaN            NaN            NaN
#
#    activity-0:00  bg+1:00
# 0            NaN     13.4
# 1            NaN     12.8
# 2            NaN     15.5
# 3            NaN     14.8
# 4            NaN     12.7
#
# [5 rows x 508 columns]

# %%
train_data.shape
# Out:
# (177024, 508)

# %%
test_data.shape
# Out:
# (3644, 507)

# %%
# Function to optimize memory usage by downcasting
def optimize_memory(df):
    for col in df.select_dtypes(include=['float']).columns:
        df[col] = pd.to_numeric(df[col], downcast='float')
    for col in df.select_dtypes(include=['int']).columns:
        df[col] = pd.to_numeric(df[col], downcast='integer')
    return df

# %%
# train_data = optimize_memory(train_data)
# test_data = optimize_memory(test_data)

# %%
# Define the target column for prediction
target = 'bg+1:00'

# %%
# Initialize the AutoGluon TabularPredictor for regression
predictor = TabularPredictor(
    label=target,                   # Target column for blood glucose level prediction
    eval_metric='rmse',             # Evaluation metric as required by the competition
    problem_type='regression'       # Set to regression for continuous value prediction
).fit(
    train_data,
    presets='best_quality',         # Best quality preset for more accurate predictions
    time_limit=3600 * 11,           # Training time limit (11 hours, adjust as needed)
    verbosity=2,                    # Detailed logs for tracking
    excluded_model_types=['KNN'],   # Exclude KNN for efficiency on large datasets
    ag_args_fit={'num_cpus': 10, 'memory_ratio': 0.8}  # Optimized CPU, GPU, and memory usage
)

# Summarize results after training
results = predictor.fit_summary()
# Out:
# No path specified. Models will be saved in: "AutogluonModels\ag-20241107_164552"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.1.1
# Python Version:     3.8.19
# Operating System:   Windows
# Platform Machine:   AMD64
# Platform Version:   10.0.22631
# CPU Count:          20
# Memory Avail:       21.51 GB / 31.82 GB (67.6%)
# Disk Space Avail:   644.78 GB / 953.00 GB (67.7%)
# ===================================================
# Presets specified: ['best_quality']
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 9900s of the 39600s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2024-11-07 20:45:55,352	INFO worker.py:1752 -- Started a local Ray instance.
# 		Context path: "AutogluonModels\ag-20241107_164552\ds_sub_fit\sub_fit_ho"
# (_dystack pid=6300) Running DyStack sub-fit ...
# (_dystack pid=6300) Beginning AutoGluon training ... Time limit = 9895s
# (_dystack pid=6300) AutoGluon will save models to "AutogluonModels\ag-20241107_164552\ds_sub_fit\sub_fit_ho"
# (_dystack pid=6300) Train Data Rows:    157354
# (_dystack pid=6300) Train Data Columns: 507
# (_dystack pid=6300) Label Column:       bg+1:00
# (_dystack pid=6300) Problem Type:       regression
# (_dystack pid=6300) Preprocessing data ...
# (_dystack pid=6300) Using Feature Generators to preprocess the data ...
# (_dystack pid=6300) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=6300) 	Available Memory:                    19123.41 MB
# (_dystack pid=6300) 	Train Data (Original)  Memory Usage: 897.99 MB (4.7% of available memory)
# (_dystack pid=6300) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=6300) 	Stage 1 Generators:
# (_dystack pid=6300) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=6300) 	Stage 2 Generators:
# (_dystack pid=6300) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=6300) 	Stage 3 Generators:
# (_dystack pid=6300) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=6300) 		Fitting CategoryFeatureGenerator...
# (_dystack pid=6300) 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# (_dystack pid=6300) 		Fitting DatetimeFeatureGenerator...
# (_dystack pid=6300) 	Stage 4 Generators:
# (_dystack pid=6300) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=6300) 	Stage 5 Generators:
# (_dystack pid=6300) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=6300) 	Unused Original Features (Count: 1): ['id']
# (_dystack pid=6300) 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# (_dystack pid=6300) 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# (_dystack pid=6300) 		These features do not need to be present at inference time.
# (_dystack pid=6300) 		('object', []) : 1 | ['id']
# (_dystack pid=6300) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=6300) 		('float', [])                      : 432 | ['bg-5:55', 'bg-5:50', 'bg-5:45', 'bg-5:40', 'bg-5:35', ...]
# (_dystack pid=6300) 		('object', [])                     :  73 | ['p_num', 'activity-5:55', 'activity-5:50', 'activity-5:45', 'activity-5:40', ...]
# (_dystack pid=6300) 		('object', ['datetime_as_object']) :   1 | ['time']
# (_dystack pid=6300) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=6300) 		('category', [])             :  73 | ['p_num', 'activity-5:55', 'activity-5:50', 'activity-5:45', 'activity-5:40', ...]
# (_dystack pid=6300) 		('float', [])                : 432 | ['bg-5:55', 'bg-5:50', 'bg-5:45', 'bg-5:40', 'bg-5:35', ...]
# (_dystack pid=6300) 		('int', ['datetime_as_int']) :   1 | ['time']
# (_dystack pid=6300) 	14.2s = Fit runtime
# (_dystack pid=6300) 	506 features in original data used to generate 506 features in processed data.
# (_dystack pid=6300) 	Train Data (Processed) Memory Usage: 530.82 MB (2.8% of available memory)
# (_dystack pid=6300) Data preprocessing and feature engineering runtime = 15.74s ...
# (_dystack pid=6300) AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# (_dystack pid=6300) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=6300) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=6300) Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=6300) User-specified model hyperparameters to be fit:
# (_dystack pid=6300) {
# (_dystack pid=6300) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=6300) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# (_dystack pid=6300) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=6300) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=6300) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=6300) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=6300) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=6300) 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# (_dystack pid=6300) }
# (_dystack pid=6300) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=6300) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=6300) Fitting 106 L1 models ...
# (_dystack pid=6300) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 6584.39s of the 9879.06s of remaining time.
# (_dystack pid=6300) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 18.38% memory usage per fold, 73.52%/80.00% total).
# (_dystack pid=6300) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=18.38%)
# (_ray_fit pid=26080) [1000]	valid_set's rmse: 1.70433
# (_ray_fit pid=26080) [2000]	valid_set's rmse: 1.62611 [repeated 2x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/ray-logging.html#log-deduplication for more options.)
# (_ray_fit pid=26080) [3000]	valid_set's rmse: 1.57209 [repeated 2x across cluster]
# (_ray_fit pid=26080) [4000]	valid_set's rmse: 1.53086 [repeated 2x across cluster]
# (_ray_fit pid=26080) [5000]	valid_set's rmse: 1.49829 [repeated 2x across cluster]
# (_ray_fit pid=26184) [5000]	valid_set's rmse: 1.5009
# (_ray_fit pid=26080) [6000]	valid_set's rmse: 1.46952
# (_ray_fit pid=26184) [7000]	valid_set's rmse: 1.45227 [repeated 2x across cluster]
# (_ray_fit pid=26184) [8000]	valid_set's rmse: 1.43268 [repeated 2x across cluster]
# (_ray_fit pid=26184) [9000]	valid_set's rmse: 1.41625 [repeated 2x across cluster]
# (_ray_fit pid=26184) [10000]	valid_set's rmse: 1.40117 [repeated 2x across cluster]
# (_ray_fit pid=26080) [10000]	valid_set's rmse: 1.39345
# (_ray_fit pid=17800) [1000]	valid_set's rmse: 1.71966
# (_ray_fit pid=26852) [1000]	valid_set's rmse: 1.72851
# (_ray_fit pid=17800) [2000]	valid_set's rmse: 1.63875
# (_ray_fit pid=26852) [2000]	valid_set's rmse: 1.64613
# (_ray_fit pid=17800) [3000]	valid_set's rmse: 1.5857
# (_ray_fit pid=26852) [3000]	valid_set's rmse: 1.58948
# (_ray_fit pid=17800) [4000]	valid_set's rmse: 1.54503
# (_ray_fit pid=26852) [4000]	valid_set's rmse: 1.55073
# (_ray_fit pid=17800) [5000]	valid_set's rmse: 1.51094
# (_ray_fit pid=26852) [5000]	valid_set's rmse: 1.51722
# (_ray_fit pid=17800) [6000]	valid_set's rmse: 1.48323
# (_ray_fit pid=26852) [6000]	valid_set's rmse: 1.48902
# (_ray_fit pid=17800) [7000]	valid_set's rmse: 1.46109
# (_ray_fit pid=26852) [7000]	valid_set's rmse: 1.4664
# (_ray_fit pid=17800) [8000]	valid_set's rmse: 1.44235
# (_ray_fit pid=26852) [8000]	valid_set's rmse: 1.4455
# (_ray_fit pid=17800) [9000]	valid_set's rmse: 1.42493
# (_ray_fit pid=26852) [9000]	valid_set's rmse: 1.42744
# (_ray_fit pid=17800) [10000]	valid_set's rmse: 1.41026
# (_ray_fit pid=26852) [10000]	valid_set's rmse: 1.41206
# (_ray_fit pid=7524) [1000]	valid_set's rmse: 1.74174
# (_ray_fit pid=15480) [1000]	valid_set's rmse: 1.7126
# (_ray_fit pid=7524) [2000]	valid_set's rmse: 1.6648
# (_ray_fit pid=15480) [2000]	valid_set's rmse: 1.63493
# (_ray_fit pid=7524) [3000]	valid_set's rmse: 1.61034
# (_ray_fit pid=15480) [3000]	valid_set's rmse: 1.58188
# (_ray_fit pid=7524) [4000]	valid_set's rmse: 1.56743
# (_ray_fit pid=15480) [4000]	valid_set's rmse: 1.54121
# (_ray_fit pid=7524) [5000]	valid_set's rmse: 1.53406
# (_ray_fit pid=15480) [5000]	valid_set's rmse: 1.50856
# (_ray_fit pid=7524) [6000]	valid_set's rmse: 1.50798
# (_ray_fit pid=15480) [6000]	valid_set's rmse: 1.482
# (_ray_fit pid=7524) [7000]	valid_set's rmse: 1.4852
# (_ray_fit pid=15480) [7000]	valid_set's rmse: 1.4591
# (_ray_fit pid=7524) [8000]	valid_set's rmse: 1.46494
# (_ray_fit pid=15480) [8000]	valid_set's rmse: 1.44001
# (_ray_fit pid=7524) [9000]	valid_set's rmse: 1.44785
# (_ray_fit pid=15480) [9000]	valid_set's rmse: 1.42295
# (_ray_fit pid=7524) [10000]	valid_set's rmse: 1.4311
# (_ray_fit pid=15480) [10000]	valid_set's rmse: 1.40693
# (_ray_fit pid=25984) [1000]	valid_set's rmse: 1.73364
# (_ray_fit pid=8984) [1000]	valid_set's rmse: 1.731
# (_ray_fit pid=25984) [2000]	valid_set's rmse: 1.65212
# (_ray_fit pid=8984) [2000]	valid_set's rmse: 1.65002
# (_ray_fit pid=25984) [3000]	valid_set's rmse: 1.59861
# (_ray_fit pid=8984) [3000]	valid_set's rmse: 1.59732
# (_ray_fit pid=25984) [4000]	valid_set's rmse: 1.5584
# (_ray_fit pid=8984) [4000]	valid_set's rmse: 1.55724
# (_ray_fit pid=25984) [5000]	valid_set's rmse: 1.52598
# (_ray_fit pid=8984) [5000]	valid_set's rmse: 1.52319
# (_ray_fit pid=25984) [6000]	valid_set's rmse: 1.49773
# (_ray_fit pid=8984) [6000]	valid_set's rmse: 1.49606
# (_ray_fit pid=25984) [7000]	valid_set's rmse: 1.47319
# (_ray_fit pid=8984) [7000]	valid_set's rmse: 1.47445
# (_ray_fit pid=25984) [8000]	valid_set's rmse: 1.45267
# (_ray_fit pid=8984) [8000]	valid_set's rmse: 1.45468
# (_ray_fit pid=25984) [9000]	valid_set's rmse: 1.43569
# (_ray_fit pid=8984) [9000]	valid_set's rmse: 1.43699
# (_ray_fit pid=25984) [10000]	valid_set's rmse: 1.41959
# (_dystack pid=6300) 	-1.4121	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	2162.05s	 = Training   runtime
# (_dystack pid=6300) 	26.96s	 = Validation runtime
# (_dystack pid=6300) Fitting model: LightGBM_BAG_L1 ... Training model for up to 4413.16s of the 7707.82s of remaining time.
# (_dystack pid=6300) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.73% memory usage per fold, 66.91%/80.00% total).
# (_dystack pid=6300) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=16.73%)
# (_ray_fit pid=19104) [1000]	valid_set's rmse: 1.70706 [repeated 2x across cluster]
# (_ray_fit pid=19104) [2000]	valid_set's rmse: 1.62497 [repeated 2x across cluster]
# (_ray_fit pid=19104) [3000]	valid_set's rmse: 1.57349 [repeated 2x across cluster]
# (_ray_fit pid=19104) [4000]	valid_set's rmse: 1.53253 [repeated 2x across cluster]
# (_ray_fit pid=19104) [5000]	valid_set's rmse: 1.49672 [repeated 2x across cluster]
# (_ray_fit pid=19104) [6000]	valid_set's rmse: 1.47125 [repeated 2x across cluster]
# (_ray_fit pid=19104) [7000]	valid_set's rmse: 1.45009 [repeated 2x across cluster]
# (_ray_fit pid=19104) [8000]	valid_set's rmse: 1.43142 [repeated 2x across cluster]
# (_ray_fit pid=17116) [9000]	valid_set's rmse: 1.40544 [repeated 2x across cluster]
# (_ray_fit pid=19104) [10000]	valid_set's rmse: 1.4039 [repeated 2x across cluster]
# (_ray_fit pid=9768) [1000]	valid_set's rmse: 1.73134 [repeated 2x across cluster]
# (_ray_fit pid=9768) [2000]	valid_set's rmse: 1.65168 [repeated 2x across cluster]
# (_ray_fit pid=9768) [3000]	valid_set's rmse: 1.59377 [repeated 2x across cluster]
# (_ray_fit pid=9768) [4000]	valid_set's rmse: 1.54969 [repeated 2x across cluster]
# (_ray_fit pid=9768) [5000]	valid_set's rmse: 1.51569 [repeated 2x across cluster]
# (_ray_fit pid=9768) [6000]	valid_set's rmse: 1.4853 [repeated 2x across cluster]
# (_ray_fit pid=9768) [7000]	valid_set's rmse: 1.46317 [repeated 2x across cluster]
# (_ray_fit pid=20704) [8000]	valid_set's rmse: 1.43366 [repeated 2x across cluster]
# (_ray_fit pid=20704) [9000]	valid_set's rmse: 1.41882 [repeated 2x across cluster]
# (_ray_fit pid=20704) [10000]	valid_set's rmse: 1.4067 [repeated 2x across cluster]
# (_ray_fit pid=18756) [1000]	valid_set's rmse: 1.7413 [repeated 2x across cluster]
# (_ray_fit pid=18756) [2000]	valid_set's rmse: 1.66449 [repeated 2x across cluster]
# (_ray_fit pid=18756) [3000]	valid_set's rmse: 1.61069 [repeated 2x across cluster]
# (_ray_fit pid=18756) [4000]	valid_set's rmse: 1.56543 [repeated 2x across cluster]
# (_ray_fit pid=18756) [5000]	valid_set's rmse: 1.5311 [repeated 2x across cluster]
# (_ray_fit pid=18756) [6000]	valid_set's rmse: 1.50342 [repeated 2x across cluster]
# (_ray_fit pid=18756) [7000]	valid_set's rmse: 1.4819 [repeated 2x across cluster]
# (_ray_fit pid=18756) [8000]	valid_set's rmse: 1.46303 [repeated 2x across cluster]
# (_ray_fit pid=18756) [9000]	valid_set's rmse: 1.44768 [repeated 2x across cluster]
# (_ray_fit pid=18756) [10000]	valid_set's rmse: 1.43446 [repeated 2x across cluster]
# (_ray_fit pid=384) [1000]	valid_set's rmse: 1.72637 [repeated 2x across cluster]
# (_ray_fit pid=384) [2000]	valid_set's rmse: 1.65048 [repeated 2x across cluster]
# (_ray_fit pid=384) [3000]	valid_set's rmse: 1.59486 [repeated 2x across cluster]
# (_ray_fit pid=384) [4000]	valid_set's rmse: 1.55244 [repeated 2x across cluster]
# (_ray_fit pid=384) [5000]	valid_set's rmse: 1.51561 [repeated 2x across cluster]
# (_ray_fit pid=17720) [6000]	valid_set's rmse: 1.49045 [repeated 2x across cluster]
# (_ray_fit pid=17720) [7000]	valid_set's rmse: 1.46935 [repeated 2x across cluster]
# (_ray_fit pid=17720) [8000]	valid_set's rmse: 1.45235 [repeated 2x across cluster]
# (_ray_fit pid=17720) [9000]	valid_set's rmse: 1.43774 [repeated 2x across cluster]
# (_ray_fit pid=17720) [10000]	valid_set's rmse: 1.42582 [repeated 2x across cluster]
# (_dystack pid=6300) 	-1.4141	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	1270.29s	 = Training   runtime
# (_dystack pid=6300) 	24.38s	 = Validation runtime
# (_dystack pid=6300) Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 3136.77s of the 6431.43s of remaining time.
# (_dystack pid=6300) 	-1.6309	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	1540.43s	 = Training   runtime
# (_dystack pid=6300) 	26.73s	 = Validation runtime
# (_dystack pid=6300) Fitting model: CatBoost_BAG_L1 ... Training model for up to 1568.13s of the 4862.79s of remaining time.
# (_dystack pid=6300) 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 20.02% memory usage per fold, 40.05%/80.00% total).
# (_dystack pid=6300) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=20.02%)
# (_dystack pid=6300) 	-1.8581	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	1261.54s	 = Training   runtime
# (_dystack pid=6300) 	0.61s	 = Validation runtime
# (_dystack pid=6300) Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 302.99s of the 3597.65s of remaining time.
# (_dystack pid=6300) 	-1.6102	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	868.9s	 = Training   runtime
# (_dystack pid=6300) 	26.17s	 = Validation runtime
# (_dystack pid=6300) Fitting model: WeightedEnsemble_L2 ... Training model for up to 658.44s of the 2700.7s of remaining time.
# (_dystack pid=6300) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.52, 'LightGBM_BAG_L1': 0.48}
# (_dystack pid=6300) 	-1.3962	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	0.18s	 = Training   runtime
# (_dystack pid=6300) 	0.0s	 = Validation runtime
# (_dystack pid=6300) Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# (_dystack pid=6300) Fitting 106 L2 models ...
# (_dystack pid=6300) Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 2700.5s of the 2700.38s of remaining time.
# (_dystack pid=6300) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.93% memory usage per fold, 67.74%/80.00% total).
# (_dystack pid=6300) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=16.93%)
# (_ray_fit pid=25740) [1000]	valid_set's rmse: 1.17452 [repeated 2x across cluster]
# (_ray_fit pid=25740) [2000]	valid_set's rmse: 1.15667 [repeated 2x across cluster]
# (_ray_fit pid=14840) [3000]	valid_set's rmse: 1.13882 [repeated 2x across cluster]
# (_ray_fit pid=25740) [4000]	valid_set's rmse: 1.13799 [repeated 2x across cluster]
# (_ray_fit pid=25740) [5000]	valid_set's rmse: 1.12964 [repeated 2x across cluster]
# (_ray_fit pid=25740) [6000]	valid_set's rmse: 1.12367 [repeated 2x across cluster]
# (_ray_fit pid=25740) [7000]	valid_set's rmse: 1.11762 [repeated 2x across cluster]
# (_ray_fit pid=25740) [8000]	valid_set's rmse: 1.11214 [repeated 2x across cluster]
# (_ray_fit pid=25740) [9000]	valid_set's rmse: 1.10846 [repeated 2x across cluster]
# (_ray_fit pid=25740) [10000]	valid_set's rmse: 1.1049 [repeated 2x across cluster]
# (_ray_fit pid=21924) [1000]	valid_set's rmse: 1.17511 [repeated 2x across cluster]
# (_ray_fit pid=21924) [2000]	valid_set's rmse: 1.15684 [repeated 2x across cluster]
# (_ray_fit pid=21924) [3000]	valid_set's rmse: 1.14393 [repeated 2x across cluster]
# (_ray_fit pid=21924) [4000]	valid_set's rmse: 1.13352 [repeated 2x across cluster]
# (_ray_fit pid=21924) [5000]	valid_set's rmse: 1.12538 [repeated 2x across cluster]
# (_ray_fit pid=21924) [6000]	valid_set's rmse: 1.11817 [repeated 2x across cluster]
# (_ray_fit pid=21924) [7000]	valid_set's rmse: 1.11188 [repeated 2x across cluster]
# (_ray_fit pid=21924) [8000]	valid_set's rmse: 1.10713 [repeated 2x across cluster]
# (_ray_fit pid=21924) [9000]	valid_set's rmse: 1.10277 [repeated 2x across cluster]
# (_ray_fit pid=21924) [10000]	valid_set's rmse: 1.09862 [repeated 2x across cluster]
# (_ray_fit pid=20664) [1000]	valid_set's rmse: 1.19607 [repeated 2x across cluster]
# (_ray_fit pid=20664) [2000]	valid_set's rmse: 1.17817 [repeated 2x across cluster]
# (_ray_fit pid=20664) [3000]	valid_set's rmse: 1.16558 [repeated 2x across cluster]
# (_ray_fit pid=20664) [4000]	valid_set's rmse: 1.15478 [repeated 2x across cluster]
# (_ray_fit pid=20664) [5000]	valid_set's rmse: 1.14674 [repeated 2x across cluster]
# (_ray_fit pid=20664) [6000]	valid_set's rmse: 1.13994 [repeated 2x across cluster]
# (_ray_fit pid=20664) [7000]	valid_set's rmse: 1.13357 [repeated 2x across cluster]
# (_ray_fit pid=20664) [8000]	valid_set's rmse: 1.12869 [repeated 2x across cluster]
# (_ray_fit pid=20664) [9000]	valid_set's rmse: 1.12402 [repeated 2x across cluster]
# (_ray_fit pid=20664) [10000]	valid_set's rmse: 1.11995 [repeated 2x across cluster]
# (_ray_fit pid=16288) [1000]	valid_set's rmse: 1.17112 [repeated 2x across cluster]
# (_ray_fit pid=16288) [2000]	valid_set's rmse: 1.15113 [repeated 2x across cluster]
# (_ray_fit pid=16288) [3000]	valid_set's rmse: 1.13875 [repeated 2x across cluster]
# (_ray_fit pid=16288) [4000]	valid_set's rmse: 1.12915 [repeated 2x across cluster]
# (_ray_fit pid=16288) [5000]	valid_set's rmse: 1.12158 [repeated 2x across cluster]
# (_ray_fit pid=16288) [6000]	valid_set's rmse: 1.11483 [repeated 2x across cluster]
# (_ray_fit pid=16288) [7000]	valid_set's rmse: 1.11006 [repeated 2x across cluster]
# (_ray_fit pid=16288) [8000]	valid_set's rmse: 1.10488 [repeated 2x across cluster]
# (_ray_fit pid=16288) [9000]	valid_set's rmse: 1.1011 [repeated 2x across cluster]
# (_ray_fit pid=16288) [10000]	valid_set's rmse: 1.09715 [repeated 2x across cluster]
# (_dystack pid=6300) 	-1.1013	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	1158.64s	 = Training   runtime
# (_dystack pid=6300) 	22.24s	 = Validation runtime
# (_dystack pid=6300) Fitting model: LightGBM_BAG_L2 ... Training model for up to 1535.13s of the 1535.01s of remaining time.
# (_dystack pid=6300) 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.61% memory usage per fold, 66.44%/80.00% total).
# (_dystack pid=6300) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=16.61%)
# (_ray_fit pid=27276) [1000]	valid_set's rmse: 1.17336 [repeated 2x across cluster]
# (_ray_fit pid=27276) [2000]	valid_set's rmse: 1.15372 [repeated 2x across cluster]
# (_ray_fit pid=17884) [3000]	valid_set's rmse: 1.14391 [repeated 2x across cluster]
# (_ray_fit pid=17884) [4000]	valid_set's rmse: 1.13365 [repeated 2x across cluster]
# (_ray_fit pid=17884) [5000]	valid_set's rmse: 1.12676 [repeated 2x across cluster]
# (_ray_fit pid=17884) [6000]	valid_set's rmse: 1.12159 [repeated 2x across cluster]
# (_ray_fit pid=17884) [7000]	valid_set's rmse: 1.11693 [repeated 2x across cluster]
# (_ray_fit pid=17884) [8000]	valid_set's rmse: 1.11272 [repeated 2x across cluster]
# (_ray_fit pid=17884) [9000]	valid_set's rmse: 1.10914 [repeated 2x across cluster]
# (_ray_fit pid=17884) [10000]	valid_set's rmse: 1.10616 [repeated 2x across cluster]
# (_ray_fit pid=20720) [1000]	valid_set's rmse: 1.17601 [repeated 2x across cluster]
# (_ray_fit pid=20720) [2000]	valid_set's rmse: 1.15777 [repeated 2x across cluster]
# (_ray_fit pid=20720) [3000]	valid_set's rmse: 1.14299 [repeated 2x across cluster]
# (_ray_fit pid=20720) [4000]	valid_set's rmse: 1.13287 [repeated 2x across cluster]
# (_ray_fit pid=20720) [5000]	valid_set's rmse: 1.12548 [repeated 2x across cluster]
# (_ray_fit pid=20720) [6000]	valid_set's rmse: 1.11998 [repeated 2x across cluster]
# (_ray_fit pid=20720) [7000]	valid_set's rmse: 1.11485 [repeated 2x across cluster]
# (_ray_fit pid=20720) [8000]	valid_set's rmse: 1.11134 [repeated 2x across cluster]
# (_ray_fit pid=20720) [9000]	valid_set's rmse: 1.10799 [repeated 2x across cluster]
# (_ray_fit pid=20720) [10000]	valid_set's rmse: 1.10472 [repeated 2x across cluster]
# (_ray_fit pid=8956) [1000]	valid_set's rmse: 1.19495 [repeated 2x across cluster]
# (_ray_fit pid=8956) [2000]	valid_set's rmse: 1.1754 [repeated 2x across cluster]
# (_ray_fit pid=8956) [3000]	valid_set's rmse: 1.16294 [repeated 2x across cluster]
# (_ray_fit pid=8956) [4000]	valid_set's rmse: 1.15309 [repeated 2x across cluster]
# (_ray_fit pid=8956) [5000]	valid_set's rmse: 1.1448 [repeated 2x across cluster]
# (_ray_fit pid=8956) [6000]	valid_set's rmse: 1.13851 [repeated 2x across cluster]
# (_ray_fit pid=8956) [7000]	valid_set's rmse: 1.133 [repeated 2x across cluster]
# (_ray_fit pid=8956) [8000]	valid_set's rmse: 1.12837 [repeated 2x across cluster]
# (_ray_fit pid=8956) [9000]	valid_set's rmse: 1.1248 [repeated 2x across cluster]
# (_ray_fit pid=8956) [10000]	valid_set's rmse: 1.12189 [repeated 2x across cluster]
# (_ray_fit pid=27304) [1000]	valid_set's rmse: 1.17563 [repeated 2x across cluster]
# (_ray_fit pid=27304) [2000]	valid_set's rmse: 1.15626 [repeated 2x across cluster]
# (_ray_fit pid=27304) [3000]	valid_set's rmse: 1.14228 [repeated 2x across cluster]
# (_ray_fit pid=27304) [4000]	valid_set's rmse: 1.13288 [repeated 2x across cluster]
# (_ray_fit pid=27304) [5000]	valid_set's rmse: 1.12554 [repeated 2x across cluster]
# (_ray_fit pid=27304) [6000]	valid_set's rmse: 1.11882 [repeated 2x across cluster]
# (_ray_fit pid=27304) [7000]	valid_set's rmse: 1.11417 [repeated 2x across cluster]
# (_ray_fit pid=27304) [8000]	valid_set's rmse: 1.10976 [repeated 2x across cluster]
# (_ray_fit pid=27304) [9000]	valid_set's rmse: 1.10646 [repeated 2x across cluster]
# (_ray_fit pid=27304) [10000]	valid_set's rmse: 1.1036 [repeated 2x across cluster]
# (_dystack pid=6300) 	-1.1044	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	1193.27s	 = Training   runtime
# (_dystack pid=6300) 	19.33s	 = Validation runtime
# (_dystack pid=6300) Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 336.55s of the 336.43s of remaining time.
# (_dystack pid=6300) 	-1.193	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	1642.6s	 = Training   runtime
# (_dystack pid=6300) 	26.24s	 = Validation runtime
# (_dystack pid=6300) Fitting model: WeightedEnsemble_L3 ... Training model for up to 360.0s of the -1334.58s of remaining time.
# (_dystack pid=6300) 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.538, 'LightGBM_BAG_L2': 0.462}
# (_dystack pid=6300) 	-1.0918	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=6300) 	0.28s	 = Training   runtime
# (_dystack pid=6300) 	0.0s	 = Validation runtime
# (_dystack pid=6300) AutoGluon training complete, total runtime = 11230.39s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 196.4 rows/s (19670 batch size)
# (_dystack pid=6300) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20241107_164552\ds_sub_fit\sub_fit_ho")
# (_dystack pid=6300) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                     model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val     fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0         LightGBM_BAG_L2      -1.016252  -1.104350  root_mean_squared_error       28.089902     124.178461  8296.491603                 8.385001               19.329000        1193.272993            2       True          8
# 1     WeightedEnsemble_L3      -1.016527  -1.091797  root_mean_squared_error       37.046195     146.420182  9455.411627                 0.007000                0.002000           0.280449            3       True         10
# 2       LightGBMXT_BAG_L2      -1.023870  -1.101289  root_mean_squared_error       28.654194     127.089182  8261.858184                 8.949292               22.239722        1158.639575            2       True          7
# 3  RandomForestMSE_BAG_L2      -1.162391  -1.192993  root_mean_squared_error       20.394665     131.085825  8745.817509                 0.689764               26.236365        1642.598900            2       True          9
# 4     WeightedEnsemble_L2      -1.413719  -1.396231  root_mean_squared_error       17.746736      51.336784  3432.525265                 0.010002                0.002000           0.180000            2       True          6
# 5         LightGBM_BAG_L1      -1.417619  -1.414065  root_mean_squared_error        8.513482      24.376009  1270.294967                 8.513482               24.376009        1270.294967            1       True          2
# 6       LightGBMXT_BAG_L1      -1.419405  -1.412057  root_mean_squared_error        9.223252      26.958775  2162.050298                 9.223252               26.958775        2162.050298            1       True          1
# 7    ExtraTreesMSE_BAG_L1      -1.633527  -1.610169  root_mean_squared_error        0.694308      26.167988   868.904804                 0.694308               26.167988         868.904804            1       True          5
# 8  RandomForestMSE_BAG_L1      -1.655150  -1.630861  root_mean_squared_error        0.686960      26.734929  1540.431112                 0.686960               26.734929        1540.431112            1       True          3
# 9         CatBoost_BAG_L1      -1.888589  -1.858109  root_mean_squared_error        0.586899       0.611760  1261.537428                 0.586899                0.611760        1261.537428            1       True          4
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	11278s	 = DyStack   runtime |	28322s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 28322s
# AutoGluon will save models to "AutogluonModels\ag-20241107_164552"
# Train Data Rows:    177024
# Train Data Columns: 507
# Label Column:       bg+1:00
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    22856.53 MB
# 	Train Data (Original)  Memory Usage: 1010.71 MB (4.4% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 		Fitting CategoryFeatureGenerator...
# 			Fitting CategoryMemoryMinimizeFeatureGenerator...
# 		Fitting DatetimeFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Unused Original Features (Count: 1): ['id']
# 		These features were not used to generate any of the output features. Add a feature generator compatible with these features to utilize them.
# 		Features can also be unused if they carry very little information, such as being categorical but having almost entirely unique values or being duplicates of other features.
# 		These features do not need to be present at inference time.
# 		('object', []) : 1 | ['id']
# 	Types of features in original data (raw dtype, special dtypes):
# 		('float', [])                      : 432 | ['bg-5:55', 'bg-5:50', 'bg-5:45', 'bg-5:40', 'bg-5:35', ...]
# 		('object', [])                     :  73 | ['p_num', 'activity-5:55', 'activity-5:50', 'activity-5:45', 'activity-5:40', ...]
# 		('object', ['datetime_as_object']) :   1 | ['time']
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('category', [])             :  73 | ['p_num', 'activity-5:55', 'activity-5:50', 'activity-5:45', 'activity-5:40', ...]
# 		('float', [])                : 432 | ['bg-5:55', 'bg-5:50', 'bg-5:45', 'bg-5:40', 'bg-5:35', ...]
# 		('int', ['datetime_as_int']) :   1 | ['time']
# 	6.5s = Fit runtime
# 	506 features in original data used to generate 506 features in processed data.
# 	Train Data (Processed) Memory Usage: 597.17 MB (2.6% of available memory)
# Data preprocessing and feature engineering runtime = 7.33s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (112 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, 'GBMLarge'],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'KNN': [{'weights': 'uniform', 'ag_args': {'name_suffix': 'Unif'}}, {'weights': 'distance', 'ag_args': {'name_suffix': 'Dist'}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L1 models ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 18871.76s of the 28314.71s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.05% memory usage per fold, 68.21%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=17.05%)
# 	-1.393	 = Validation score   (-root_mean_squared_error)
# 	1109.33s	 = Training   runtime
# 	26.85s	 = Validation runtime
# Fitting model: LightGBM_BAG_L1 ... Training model for up to 17754.01s of the 27196.96s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.85% memory usage per fold, 67.41%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=16.85%)
# 	-1.3908	 = Validation score   (-root_mean_squared_error)
# 	1182.16s	 = Training   runtime
# 	22.88s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L1 ... Training model for up to 16565.39s of the 26008.34s of remaining time.
# 	-1.613	 = Validation score   (-root_mean_squared_error)
# 	1551.28s	 = Training   runtime
# 	35.39s	 = Validation runtime
# Fitting model: CatBoost_BAG_L1 ... Training model for up to 14977.28s of the 24420.23s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.61% memory usage per fold, 70.43%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=17.61%)
# 	-1.6239	 = Validation score   (-root_mean_squared_error)
# 	11988.68s	 = Training   runtime
# 	0.57s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L1 ... Training model for up to 2985.09s of the 12428.03s of remaining time.
# 	-1.5944	 = Validation score   (-root_mean_squared_error)
# 	545.33s	 = Training   runtime
# 	34.81s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L1 ... Training model for up to 2403.59s of the 11846.54s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 29.37% memory usage per fold, 58.75%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=29.37%)
# 	Warning: Exception caused NeuralNetFastAI_BAG_L1 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=26248, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=26248, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# Fitting model: XGBoost_BAG_L1 ... Training model for up to 2398.98s of the 11841.92s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 22.86% memory usage per fold, 45.72%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=22.86%)
# 2024-11-08 04:28:36,469	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): ray::_ray_fit() (pid=13040, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=13040, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# 	-1.517	 = Validation score   (-root_mean_squared_error)
# 	1932.44s	 = Training   runtime
# 	9.3s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L1 ... Training model for up to 462.37s of the 9905.32s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 15.97% memory usage per fold, 63.89%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=15.97%)
# 	-1.9889	 = Validation score   (-root_mean_squared_error)
# 	378.81s	 = Training   runtime
# 	9.45s	 = Validation runtime
# Fitting model: LightGBMLarge_BAG_L1 ... Training model for up to 78.96s of the 9521.91s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 18.37% memory usage per fold, 73.50%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=18.37%)
# 	-1.863	 = Validation score   (-root_mean_squared_error)
# 	72.85s	 = Training   runtime
# 	0.88s	 = Validation runtime
# Fitting model: CatBoost_r177_BAG_L1 ... Training model for up to 2.54s of the 9445.49s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.55% memory usage per fold, 70.20%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=17.55%)
# 	Time limit exceeded... Skipping CatBoost_r177_BAG_L1.
# 2024-11-08 05:08:33,064	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 1887.18s of the 9440.03s of remaining time.
# 	Ensemble Weights: {'LightGBM_BAG_L1': 0.52, 'LightGBMXT_BAG_L1': 0.48}
# 	-1.3754	 = Validation score   (-root_mean_squared_error)
# 	0.38s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Excluded models: ['KNN'] (Specified by `excluded_model_types`)
# Fitting 106 L2 models ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 9439.62s of the 9439.47s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.76% memory usage per fold, 71.03%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=17.76%)
# 	-1.0575	 = Validation score   (-root_mean_squared_error)
# 	1154.96s	 = Training   runtime
# 	26.88s	 = Validation runtime
# Fitting model: LightGBM_BAG_L2 ... Training model for up to 8277.66s of the 8277.51s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 17.70% memory usage per fold, 70.81%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=17.70%)
# 	-1.0608	 = Validation score   (-root_mean_squared_error)
# 	1207.16s	 = Training   runtime
# 	27.08s	 = Validation runtime
# Fitting model: RandomForestMSE_BAG_L2 ... Training model for up to 7063.05s of the 7062.9s of remaining time.
# 	-1.1512	 = Validation score   (-root_mean_squared_error)
# 	1718.47s	 = Training   runtime
# 	36.34s	 = Validation runtime
# Fitting model: CatBoost_BAG_L2 ... Training model for up to 5306.88s of the 5306.73s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 18.61% memory usage per fold, 74.44%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=18.61%)
# 	-1.1334	 = Validation score   (-root_mean_squared_error)
# 	4252.42s	 = Training   runtime
# 	0.53s	 = Validation runtime
# Fitting model: ExtraTreesMSE_BAG_L2 ... Training model for up to 1050.93s of the 1050.77s of remaining time.
# 	-1.1578	 = Validation score   (-root_mean_squared_error)
# 	751.11s	 = Training   runtime
# 	36.03s	 = Validation runtime
# Fitting model: NeuralNetFastAI_BAG_L2 ... Training model for up to 262.43s of the 262.28s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 31.18% memory usage per fold, 62.37%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=31.18%)
# 	Warning: Exception caused NeuralNetFastAI_BAG_L2 to fail during training (ImportError)... Skipping this model.
# 		ray::_ray_fit() (pid=23568, ip=127.0.0.1)
# ModuleNotFoundError: No module named 'fastai'
#
# During handling of the above exception, another exception occurred:
#
# ray::_ray_fit() (pid=23568, ip=127.0.0.1)
#   File "python\ray\_raylet.pyx", line 1883, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1984, in ray._raylet.execute_task
#   File "python\ray\_raylet.pyx", line 1889, in ray._raylet.execute_task
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\ensemble\fold_fitting_strategy.py", line 402, in _ray_fit
#     fold_model.fit(X=X_fold, y=y_fold, X_val=X_val_fold, y_val=y_val_fold, time_limit=time_limit_fold, **resources, **kwargs_fold)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\models\abstract\abstract_model.py", line 856, in fit
#     out = self._fit(**kwargs)
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\tabular\models\fastainn\tabular_nn_fastai.py", line 213, in _fit
#     try_import_fastai()
#   File "C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\common\utils\try_import.py", line 122, in try_import_fastai
#     raise ImportError(f"Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]=={__version__}`. ")
# ImportError: Import fastai failed. A quick tip is to install via `pip install autogluon.tabular[fastai]==1.1.1`.
# Fitting model: XGBoost_BAG_L2 ... Training model for up to 257.67s of the 257.52s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 2 folds in parallel instead (Estimated 24.26% memory usage per fold, 48.52%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=24.26%)
# 2024-11-08 07:41:40,834	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# 	-1.1459	 = Validation score   (-root_mean_squared_error)
# 	217.51s	 = Training   runtime
# 	5.19s	 = Validation runtime
# Fitting model: NeuralNetTorch_BAG_L2 ... Training model for up to 36.66s of the 36.5s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 16.63% memory usage per fold, 66.51%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=16.63%)
# 	Time limit exceeded... Skipping NeuralNetTorch_BAG_L2.
# 2024-11-08 07:45:40,896	ERROR worker.py:406 -- Unhandled error (suppress with 'RAY_IGNORE_UNHANDLED_ERRORS=1'): The worker died unexpectedly while executing this task. Check python-core-worker-*.log files for more information.
# Fitting model: LightGBMLarge_BAG_L2 ... Training model for up to 12.54s of the 12.38s of remaining time.
# 	Memory not enough to fit 8 folds in parallel. Will train 4 folds in parallel instead (Estimated 19.09% memory usage per fold, 76.38%/80.00% total).
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=10, gpus=0, memory=19.09%)
# 	-2.9231	 = Validation score   (-root_mean_squared_error)
# 	23.33s	 = Training   runtime
# 	0.69s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 943.96s of the -14.88s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L2': 0.538, 'LightGBM_BAG_L2': 0.462}
# 	-1.0482	 = Validation score   (-root_mean_squared_error)
# 	0.46s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 28338.07s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 166.8 rows/s (22128 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("AutogluonModels\ag-20241107_164552")
# *** Summary of fit() ***
# Estimated performance of each model:
#                      model  score_val              eval_metric  pred_time_val      fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0      WeightedEnsemble_L3  -1.048201  root_mean_squared_error     194.085680  21123.480018                0.002998           0.462963            3       True         17
# 1        LightGBMXT_BAG_L2  -1.057460  root_mean_squared_error     167.005683  19915.854228               26.878571        1154.956234            2       True         10
# 2          LightGBM_BAG_L2  -1.060814  root_mean_squared_error     167.204112  19968.060821               27.076999        1207.162827            2       True         11
# 3          CatBoost_BAG_L2  -1.133447  root_mean_squared_error     140.658111  23013.314626                0.530998        4252.416632            2       True         13
# 4           XGBoost_BAG_L2  -1.145858  root_mean_squared_error     145.317335  18978.404713                5.190223         217.506719            2       True         15
# 5   RandomForestMSE_BAG_L2  -1.151171  root_mean_squared_error     176.467281  20479.365496               36.340168        1718.467502            2       True         12
# 6     ExtraTreesMSE_BAG_L2  -1.157772  root_mean_squared_error     176.161943  19512.007148               36.034830         751.109153            2       True         14
# 7      WeightedEnsemble_L2  -1.375363  root_mean_squared_error      49.732991   2291.881114                0.002000           0.384508            2       True          9
# 8          LightGBM_BAG_L1  -1.390787  root_mean_squared_error      22.883993   1182.164187               22.883993        1182.164187            1       True          2
# 9        LightGBMXT_BAG_L1  -1.393025  root_mean_squared_error      26.846997   1109.332419               26.846997        1109.332419            1       True          1
# 10          XGBoost_BAG_L1  -1.516959  root_mean_squared_error       9.302714   1932.444863                9.302714        1932.444863            1       True          6
# 11    ExtraTreesMSE_BAG_L1  -1.594426  root_mean_squared_error      34.806544    545.332846               34.806544         545.332846            1       True          5
# 12  RandomForestMSE_BAG_L1  -1.612984  root_mean_squared_error      35.386384   1551.282589               35.386384        1551.282589            1       True          3
# 13         CatBoost_BAG_L1  -1.623939  root_mean_squared_error       0.573258  11988.677634                0.573258       11988.677634            1       True          4
# 14    LightGBMLarge_BAG_L1  -1.863004  root_mean_squared_error       0.880000     72.854079                0.880000          72.854079            1       True          8
# 15   NeuralNetTorch_BAG_L1  -1.988885  root_mean_squared_error       9.447222    378.809378                9.447222         378.809378            1       True          7
# 16    LightGBMLarge_BAG_L2  -2.923095  root_mean_squared_error     140.817112  18784.226108                0.689999          23.328113            2       True         16
# Number of models trained: 17
# Types of models trained:
# {'StackerEnsembleModel_XT', 'StackerEnsembleModel_RF', 'StackerEnsembleModel_LGB', 'StackerEnsembleModel_TabularNeuralNetTorch', 'WeightedEnsembleModel', 'StackerEnsembleModel_XGBoost', 'StackerEnsembleModel_CatBoost'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('category', [])             :  73 | ['p_num', 'activity-5:55', 'activity-5:50', 'activity-5:45', 'activity-5:40', ...]
# ('float', [])                : 432 | ['bg-5:55', 'bg-5:50', 'bg-5:45', 'bg-5:40', 'bg-5:35', ...]
# ('int', ['datetime_as_int']) :   1 | ['time']
# *** End of fit() summary ***
# C:\Users\Hi\anaconda3\envs\gpu_env\lib\site-packages\autogluon\core\utils\plots.py:169: UserWarning: AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"
#   warnings.warn('AutoGluon summary plots cannot be created because bokeh is not installed. To see plots, please do: "pip install bokeh==2.0.1"')

# %%
# Prepare test data without the target column for prediction
test_data_no_target = test_data.drop(columns=[target], errors='ignore')

# %%
# Make predictions on the test data
predictions = predictor.predict(test_data_no_target)

# %%
# Prepare the submission file
submission = pd.DataFrame({'id': test_data['id'], target: predictions})
submission.to_csv("submission.csv", index=False)
print("Submission file saved as submission.csv.")
# Out:
# Submission file saved as submission.csv.

# %%
results
# Out:
# {'model_types': {'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L1': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L1': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L1': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L1': 'StackerEnsembleModel_XT',
#   'XGBoost_BAG_L1': 'StackerEnsembleModel_XGBoost',
#   'NeuralNetTorch_BAG_L1': 'StackerEnsembleModel_TabularNeuralNetTorch',
#   'LightGBMLarge_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'LightGBM_BAG_L2': 'StackerEnsembleModel_LGB',
#   'RandomForestMSE_BAG_L2': 'StackerEnsembleModel_RF',
#   'CatBoost_BAG_L2': 'StackerEnsembleModel_CatBoost',
#   'ExtraTreesMSE_BAG_L2': 'StackerEnsembleModel_XT',
#   'XGBoost_BAG_L2': 'StackerEnsembleModel_XGBoost',
#   'LightGBMLarge_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'LightGBMXT_BAG_L1': -1.3930247603230939,
#   'LightGBM_BAG_L1': -1.3907872225612747,
#   'RandomForestMSE_BAG_L1': -1.612983644555464,
#   'CatBoost_BAG_L1': -1.6239388529918357,
#   'ExtraTreesMSE_BAG_L1': -1.594425704765528,
#   'XGBoost_BAG_L1': -1.5169587209212745,
#   'NeuralNetTorch_BAG_L1': -1.9888851630853772,
#   'LightGBMLarge_BAG_L1': -1.8630037127627013,
#   'WeightedEnsemble_L2': -1.3753630140549813,
#   'LightGBMXT_BAG_L2': -1.0574604562116965,
#   'LightGBM_BAG_L2': -1.0608136396492363,
#   'RandomForestMSE_BAG_L2': -1.1511707314282473,
#   'CatBoost_BAG_L2': -1.133447452216226,
#   'ExtraTreesMSE_BAG_L2': -1.1577724360760957,
#   'XGBoost_BAG_L2': -1.1458579326989917,
#   'LightGBMLarge_BAG_L2': -2.9230946866289402,
#   'WeightedEnsemble_L3': -1.0482013741690304},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'LightGBM_BAG_L1': ['LightGBM_BAG_L1'],
#   'RandomForestMSE_BAG_L1': ['RandomForestMSE_BAG_L1'],
#   'CatBoost_BAG_L1': ['CatBoost_BAG_L1'],
#   'ExtraTreesMSE_BAG_L1': ['ExtraTreesMSE_BAG_L1'],
#   'XGBoost_BAG_L1': ['XGBoost_BAG_L1'],
#   'NeuralNetTorch_BAG_L1': ['NeuralNetTorch_BAG_L1'],
#   'LightGBMLarge_BAG_L1': ['LightGBMLarge_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'LightGBM_BAG_L2': ['LightGBM_BAG_L2'],
#   'RandomForestMSE_BAG_L2': ['RandomForestMSE_BAG_L2'],
#   'CatBoost_BAG_L2': ['CatBoost_BAG_L2'],
#   'ExtraTreesMSE_BAG_L2': ['ExtraTreesMSE_BAG_L2'],
#   'XGBoost_BAG_L2': ['XGBoost_BAG_L2'],
#   'LightGBMLarge_BAG_L2': ['LightGBMLarge_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'LightGBMXT_BAG_L1': 1109.3324189186096,
#   'LightGBM_BAG_L1': 1182.1641869544983,
#   'RandomForestMSE_BAG_L1': 1551.2825887203217,
#   'CatBoost_BAG_L1': 11988.677634000778,
#   'ExtraTreesMSE_BAG_L1': 545.3328461647034,
#   'XGBoost_BAG_L1': 1932.4448628425598,
#   'NeuralNetTorch_BAG_L1': 378.8093783855438,
#   'LightGBMLarge_BAG_L1': 72.85407853126526,
#   'WeightedEnsemble_L2': 0.3845076560974121,
#   'LightGBMXT_BAG_L2': 1154.9562339782715,
#   'LightGBM_BAG_L2': 1207.162826538086,
#   'RandomForestMSE_BAG_L2': 1718.4675018787384,
#   'CatBoost_BAG_L2': 4252.416631698608,
#   'ExtraTreesMSE_BAG_L2': 751.1091532707214,
#   'XGBoost_BAG_L2': 217.50671887397766,
#   'LightGBMLarge_BAG_L2': 23.328113317489624,
#   'WeightedEnsemble_L3': 0.4629631042480469},
#  'model_pred_times': {'LightGBMXT_BAG_L1': 26.846997499465942,
#   'LightGBM_BAG_L1': 22.88399314880371,
#   'RandomForestMSE_BAG_L1': 35.38638353347778,
#   'CatBoost_BAG_L1': 0.5732583999633789,
#   'ExtraTreesMSE_BAG_L1': 34.806544065475464,
#   'XGBoost_BAG_L1': 9.302713871002197,
#   'NeuralNetTorch_BAG_L1': 9.447221994400024,
#   'LightGBMLarge_BAG_L1': 0.8800003528594971,
#   'WeightedEnsemble_L2': 0.002000093460083008,
#   'LightGBMXT_BAG_L2': 26.878570556640625,
#   'LightGBM_BAG_L2': 27.076998949050903,
#   'RandomForestMSE_BAG_L2': 36.340168476104736,
#   'CatBoost_BAG_L2': 0.5309984683990479,
#   'ExtraTreesMSE_BAG_L2': 36.03482985496521,
#   'XGBoost_BAG_L2': 5.190222501754761,
#   'LightGBMLarge_BAG_L2': 0.6899988651275635,
#   'WeightedEnsemble_L3': 0.002997875213623047},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'NeuralNetTorch_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L1': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBM_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'RandomForestMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'CatBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'ExtraTreesMSE_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True,
#    'use_child_oof': True},
#   'XGBoost_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'LightGBMLarge_BAG_L2': {'use_orig_features': True,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'max_base_models': 25,
#    'max_base_models_per_type': 5,
#    'save_bag_folds': True}},
#  'leaderboard':                      model  score_val              eval_metric  pred_time_val  \
#  0      WeightedEnsemble_L3  -1.048201  root_mean_squared_error     194.085680
#  1        LightGBMXT_BAG_L2  -1.057460  root_mean_squared_error     167.005683
#  2          LightGBM_BAG_L2  -1.060814  root_mean_squared_error     167.204112
#  3          CatBoost_BAG_L2  -1.133447  root_mean_squared_error     140.658111
#  4           XGBoost_BAG_L2  -1.145858  root_mean_squared_error     145.317335
#  5   RandomForestMSE_BAG_L2  -1.151171  root_mean_squared_error     176.467281
#  6     ExtraTreesMSE_BAG_L2  -1.157772  root_mean_squared_error     176.161943
#  7      WeightedEnsemble_L2  -1.375363  root_mean_squared_error      49.732991
#  8          LightGBM_BAG_L1  -1.390787  root_mean_squared_error      22.883993
#  9        LightGBMXT_BAG_L1  -1.393025  root_mean_squared_error      26.846997
#  10          XGBoost_BAG_L1  -1.516959  root_mean_squared_error       9.302714
#  11    ExtraTreesMSE_BAG_L1  -1.594426  root_mean_squared_error      34.806544
#  12  RandomForestMSE_BAG_L1  -1.612984  root_mean_squared_error      35.386384
#  13         CatBoost_BAG_L1  -1.623939  root_mean_squared_error       0.573258
#  14    LightGBMLarge_BAG_L1  -1.863004  root_mean_squared_error       0.880000
#  15   NeuralNetTorch_BAG_L1  -1.988885  root_mean_squared_error       9.447222
#  16    LightGBMLarge_BAG_L2  -2.923095  root_mean_squared_error     140.817112
#
#          fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0   21123.480018                0.002998           0.462963            3
#  1   19915.854228               26.878571        1154.956234            2
#  2   19968.060821               27.076999        1207.162827            2
#  3   23013.314626                0.530998        4252.416632            2
#  4   18978.404713                5.190223         217.506719            2
#  5   20479.365496               36.340168        1718.467502            2
#  6   19512.007148               36.034830         751.109153            2
#  7    2291.881114                0.002000           0.384508            2
#  8    1182.164187               22.883993        1182.164187            1
#  9    1109.332419               26.846997        1109.332419            1
#  10   1932.444863                9.302714        1932.444863            1
#  11    545.332846               34.806544         545.332846            1
#  12   1551.282589               35.386384        1551.282589            1
#  13  11988.677634                0.573258       11988.677634            1
#  14     72.854079                0.880000          72.854079            1
#  15    378.809378                9.447222         378.809378            1
#  16  18784.226108                0.689999          23.328113            2
#
#      can_infer  fit_order
#  0        True         17
#  1        True         10
#  2        True         11
#  3        True         13
#  4        True         15
#  5        True         12
#  6        True         14
#  7        True          9
#  8        True          2
#  9        True          1
#  10       True          6
#  11       True          5
#  12       True          3
#  13       True          4
#  14       True          8
#  15       True          7
#  16       True         16  }

# %%
# Get the leaderboard to see the performance of the models
leaderboard = predictor.leaderboard(silent=True)

# Print the leaderboard for reference
leaderboard
# Out:
#                      model  score_val              eval_metric  pred_time_val  \
# 0      WeightedEnsemble_L3  -1.048201  root_mean_squared_error     194.085680
# 1        LightGBMXT_BAG_L2  -1.057460  root_mean_squared_error     167.005683
# 2          LightGBM_BAG_L2  -1.060814  root_mean_squared_error     167.204112
# 3          CatBoost_BAG_L2  -1.133447  root_mean_squared_error     140.658111
# 4           XGBoost_BAG_L2  -1.145858  root_mean_squared_error     145.317335
# 5   RandomForestMSE_BAG_L2  -1.151171  root_mean_squared_error     176.467281
# 6     ExtraTreesMSE_BAG_L2  -1.157772  root_mean_squared_error     176.161943
# 7      WeightedEnsemble_L2  -1.375363  root_mean_squared_error      49.732991
# 8          LightGBM_BAG_L1  -1.390787  root_mean_squared_error      22.883993
# 9        LightGBMXT_BAG_L1  -1.393025  root_mean_squared_error      26.846997
# 10          XGBoost_BAG_L1  -1.516959  root_mean_squared_error       9.302714
# 11    ExtraTreesMSE_BAG_L1  -1.594426  root_mean_squared_error      34.806544
# 12  RandomForestMSE_BAG_L1  -1.612984  root_mean_squared_error      35.386384
# 13         CatBoost_BAG_L1  -1.623939  root_mean_squared_error       0.573258
# 14    LightGBMLarge_BAG_L1  -1.863004  root_mean_squared_error       0.880000
# 15   NeuralNetTorch_BAG_L1  -1.988885  root_mean_squared_error       9.447222
# 16    LightGBMLarge_BAG_L2  -2.923095  root_mean_squared_error     140.817112
#
#         fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
# 0   21123.480018                0.002998           0.462963            3
# 1   19915.854228               26.878571        1154.956234            2
# 2   19968.060821               27.076999        1207.162827            2
# 3   23013.314626                0.530998        4252.416632            2
# 4   18978.404713                5.190223         217.506719            2
# 5   20479.365496               36.340168        1718.467502            2
# 6   19512.007148               36.034830         751.109153            2
# 7    2291.881114                0.002000           0.384508            2
# 8    1182.164187               22.883993        1182.164187            1
# 9    1109.332419               26.846997        1109.332419            1
# 10   1932.444863                9.302714        1932.444863            1
# 11    545.332846               34.806544         545.332846            1
# 12   1551.282589               35.386384        1551.282589            1
# 13  11988.677634                0.573258       11988.677634            1
# 14     72.854079                0.880000          72.854079            1
# 15    378.809378                9.447222         378.809378            1
# 16  18784.226108                0.689999          23.328113            2
#
#     can_infer  fit_order
# 0        True         17
# 1        True         10
# 2        True         11
# 3        True         13
# 4        True         15
# 5        True         12
# 6        True         14
# 7        True          9
# 8        True          2
# 9        True          1
# 10       True          6
# 11       True          5
# 12       True          3
# 13       True          4
# 14       True          8
# 15       True          7
# 16       True         16

# %%
# Get the top 10 models based on the leaderboard
top_10_models = leaderboard['model'].head(10).tolist()
top_10_models
# Out:
# ['WeightedEnsemble_L3',
#  'LightGBMXT_BAG_L2',
#  'LightGBM_BAG_L2',
#  'CatBoost_BAG_L2',
#  'XGBoost_BAG_L2',
#  'RandomForestMSE_BAG_L2',
#  'ExtraTreesMSE_BAG_L2',
#  'WeightedEnsemble_L2',
#  'LightGBM_BAG_L1',
#  'LightGBMXT_BAG_L1']

# %%
# Iterate through the top 10 models and print their hyperparameters
for model in top_10_models:
    hyperparameters = predictor.info()['model_info'][model]['hyperparameters']
    print(f"Model: {model}")
    print("Hyperparameters:")
    print(hyperparameters)
    print("-" * 50)
# Out:
# Model: WeightedEnsemble_L3
# Hyperparameters:
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: LightGBMXT_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: LightGBM_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: CatBoost_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: XGBoost_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: RandomForestMSE_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# --------------------------------------------------
# Model: ExtraTreesMSE_BAG_L2
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True, 'use_child_oof': True}
# --------------------------------------------------
# Model: WeightedEnsemble_L2
# Hyperparameters:
# {'use_orig_features': False, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: LightGBM_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------
# Model: LightGBMXT_BAG_L1
# Hyperparameters:
# {'use_orig_features': True, 'max_base_models': 25, 'max_base_models_per_type': 5, 'save_bag_folds': True}
# --------------------------------------------------

# %%
# Get details of the best model
best_model = predictor.get_model_best()
print(f"Best Model: {best_model}")

# Get model hyperparameters and other info
best_model_info = predictor.info()
print(best_model_info)
# Out:
# Best Model: WeightedEnsemble_L3
# C:\Users\Hi\AppData\Local\Temp\ipykernel_8752\3617745900.py:2: DeprecationWarning: `get_model_best` has been deprecated and will be removed in version 1.2. Please use `model_best` instead. This will raise an error in the future!
#   best_model = predictor.get_model_best()
# {'path': 'AutogluonModels\\ag-20241107_164552', 'label': 'bg+1:00', 'random_state': 0, 'version': '1.1.1', 'features': ['p_num', 'time', 'bg-5:55', 'bg-5:50', 'bg-5:45', 'bg-5:40', 'bg-5:35', 'bg-5:30', 'bg-5:25', 'bg-5:20', 'bg-5:15', 'bg-5:10', 'bg-5:05', 'bg-5:00', 'bg-4:55', 'bg-4:50', 'bg-4:45', 'bg-4:40', 'bg-4:35', 'bg-4:30', 'bg-4:25', 'bg-4:20', 'bg-4:15', 'bg-4:10', 'bg-4:05', 'bg-4:00', 'bg-3:55', 'bg-3:50', 'bg-3:45', 'bg-3:40', 'bg-3:35', 'bg-3:30', 'bg-3:25', 'bg-3:20', 'bg-3:15', 'bg-3:10', 'bg-3:05', 'bg-3:00', 'bg-2:55', 'bg-2:50', 'bg-2:45', 'bg-2:40', 'bg-2:35', 'bg-2:30', 'bg-2:25', 'bg-2:20', 'bg-2:15', 'bg-2:10', 'bg-2:05', 'bg-2:00', 'bg-1:55', 'bg-1:50', 'bg-1:45', 'bg-1:40', 'bg-1:35', 'bg-1:30', 'bg-1:25', 'bg-1:20', 'bg-1:15', 'bg-1:10', 'bg-1:05', 'bg-1:00', 'bg-0:55', 'bg-0:50', 'bg-0:45', 'bg-0:40', 'bg-0:35', 'bg-0:30', 'bg-0:25', 'bg-0:20', 'bg-0:15', 'bg-0:10', 'bg-0:05', 'bg-0:00', 'insulin-5:55', 'insulin-5:50', 'insulin-5:45', 'insulin-5:40', 'insulin-5:35', 'insulin-5:30', 'insulin-5:25', 'insulin-5:20', 'insulin-5:15', 'insulin-5:10', 'insulin-5:05', 'insulin-5:00', 'insulin-4:55', 'insulin-4:50', 'insulin-4:45', 'insulin-4:40', 'insulin-4:35', 'insulin-4:30', 'insulin-4:25', 'insulin-4:20', 'insulin-4:15', 'insulin-4:10', 'insulin-4:05', 'insulin-4:00', 'insulin-3:55', 'insulin-3:50', 'insulin-3:45', 'insulin-3:40', 'insulin-3:35', 'insulin-3:30', 'insulin-3:25', 'insulin-3:20', 'insulin-3:15', 'insulin-3:10', 'insulin-3:05', 'insulin-3:00', 'insulin-2:55', 'insulin-2:50', 'insulin-2:45', 'insulin-2:40', 'insulin-2:35', 'insulin-2:30', 'insulin-2:25', 'insulin-2:20', 'insulin-2:15', 'insulin-2:10', 'insulin-2:05', 'insulin-2:00', 'insulin-1:55', 'insulin-1:50', 'insulin-1:45', 'insulin-1:40', 'insulin-1:35', 'insulin-1:30', 'insulin-1:25', 'insulin-1:20', 'insulin-1:15', 'insulin-1:10', 'insulin-1:05', 'insulin-1:00', 'insulin-0:55', 'insulin-0:50', 'insulin-0:45', 'insulin-0:40', 'insulin-0:35', 'insulin-0:30', 'insulin-0:25', 'insulin-0:20', 'insulin-0:15', 'insulin-0:10', 'insulin-0:05', 'insulin-0:00', 'carbs-5:55', 'carbs-5:50', 'carbs-5:45', 'carbs-5:40', 'carbs-5:35', 'carbs-5:30', 'carbs-5:25', 'carbs-5:20', 'carbs-5:15', 'carbs-5:10', 'carbs-5:05', 'carbs-5:00', 'carbs-4:55', 'carbs-4:50', 'carbs-4:45', 'carbs-4:40', 'carbs-4:35', 'carbs-4:30', 'carbs-4:25', 'carbs-4:20', 'carbs-4:15', 'carbs-4:10', 'carbs-4:05', 'carbs-4:00', 'carbs-3:55', 'carbs-3:50', 'carbs-3:45', 'carbs-3:40', 'carbs-3:35', 'carbs-3:30', 'carbs-3:25', 'carbs-3:20', 'carbs-3:15', 'carbs-3:10', 'carbs-3:05', 'carbs-3:00', 'carbs-2:55', 'carbs-2:50', 'carbs-2:45', 'carbs-2:40', 'carbs-2:35', 'carbs-2:30', 'carbs-2:25', 'carbs-2:20', 'carbs-2:15', 'carbs-2:10', 'carbs-2:05', 'carbs-2:00', 'carbs-1:55', 'carbs-1:50', 'carbs-1:45', 'carbs-1:40', 'carbs-1:35', 'carbs-1:30', 'carbs-1:25', 'carbs-1:20', 'carbs-1:15', 'carbs-1:10', 'carbs-1:05', 'carbs-1:00', 'carbs-0:55', 'carbs-0:50', 'carbs-0:45', 'carbs-0:40', 'carbs-0:35', 'carbs-0:30', 'carbs-0:25', 'carbs-0:20', 'carbs-0:15', 'carbs-0:10', 'carbs-0:05', 'carbs-0:00', 'hr-5:55', 'hr-5:50', 'hr-5:45', 'hr-5:40', 'hr-5:35', 'hr-5:30', 'hr-5:25', 'hr-5:20', 'hr-5:15', 'hr-5:10', 'hr-5:05', 'hr-5:00', 'hr-4:55', 'hr-4:50', 'hr-4:45', 'hr-4:40', 'hr-4:35', 'hr-4:30', 'hr-4:25', 'hr-4:20', 'hr-4:15', 'hr-4:10', 'hr-4:05', 'hr-4:00', 'hr-3:55', 'hr-3:50', 'hr-3:45', 'hr-3:40', 'hr-3:35', 'hr-3:30', 'hr-3:25', 'hr-3:20', 'hr-3:15', 'hr-3:10', 'hr-3:05', 'hr-3:00', 'hr-2:55', 'hr-2:50', 'hr-2:45', 'hr-2:40', 'hr-2:35', 'hr-2:30', 'hr-2:25', 'hr-2:20', 'hr-2:15', 'hr-2:10', 'hr-2:05', 'hr-2:00', 'hr-1:55', 'hr-1:50', 'hr-1:45', 'hr-1:40', 'hr-1:35', 'hr-1:30', 'hr-1:25', 'hr-1:20', 'hr-1:15', 'hr-1:10', 'hr-1:05', 'hr-1:00', 'hr-0:55', 'hr-0:50', 'hr-0:45', 'hr-0:40', 'hr-0:35', 'hr-0:30', 'hr-0:25', 'hr-0:20', 'hr-0:15', 'hr-0:10', 'hr-0:05', 'hr-0:00', 'steps-5:55', 'steps-5:50', 'steps-5:45', 'steps-5:40', 'steps-5:35', 'steps-5:30', 'steps-5:25', 'steps-5:20', 'steps- ...

# %%
# Feature importance
feature_importance = predictor.feature_importance(train_data)
print("Feature Importance:\n", feature_importance)
# Out:
# These features in provided data are not utilized by the predictor and will be ignored: ['id']
# Computing feature importance via permutation shuffling for 506 features using 5000 rows with 5 shuffle sets...
# 	49939.95s	= Expected runtime (9987.99s per shuffle set)
# 	31245.91s	= Actual runtime (Completed 5 of 5 shuffle sets)
# Feature Importance:
#                 importance    stddev       p_value  n  p99_high   p99_low
# bg-0:00          2.022384  0.054928  6.523384e-08  5  2.135481  1.909287
# bg-0:05          0.185313  0.014624  4.615269e-06  5  0.215423  0.155202
# p_num            0.152783  0.022164  5.169048e-05  5  0.198420  0.107146
# bg-0:10          0.006658  0.005769  3.064144e-02  5  0.018537 -0.005221
# activity-3:15   -0.000207  0.000064  9.990265e-01  5 -0.000075 -0.000339
# ...                   ...       ...           ... ..       ...       ...
# bg-0:35         -0.035206  0.002542  9.999968e-01  5 -0.029972 -0.040441
# bg-0:15         -0.040210  0.004456  9.999822e-01  5 -0.031035 -0.049385
# bg-0:20         -0.042080  0.001664  9.999997e-01  5 -0.038654 -0.045506
# bg-0:45         -0.044628  0.001173  9.999999e-01  5 -0.042212 -0.047044
# bg-0:30         -0.061769  0.002243  9.999998e-01  5 -0.057151 -0.066386
#
# [506 rows x 6 columns]

# %%
submission.head()
# Out:
#          id    bg+1:00
# 0  p01_8459   8.651827
# 1  p01_8460   4.748473
# 2  p01_8461   9.101196
# 3  p01_8462  11.132580
# 4  p01_8463   6.888596

# %%
feature_importance
# Out:
#                importance    stddev       p_value  n  p99_high   p99_low
# bg-0:00          2.022384  0.054928  6.523384e-08  5  2.135481  1.909287
# bg-0:05          0.185313  0.014624  4.615269e-06  5  0.215423  0.155202
# p_num            0.152783  0.022164  5.169048e-05  5  0.198420  0.107146
# bg-0:10          0.006658  0.005769  3.064144e-02  5  0.018537 -0.005221
# activity-3:15   -0.000207  0.000064  9.990265e-01  5 -0.000075 -0.000339
# ...                   ...       ...           ... ..       ...       ...
# bg-0:35         -0.035206  0.002542  9.999968e-01  5 -0.029972 -0.040441
# bg-0:15         -0.040210  0.004456  9.999822e-01  5 -0.031035 -0.049385
# bg-0:20         -0.042080  0.001664  9.999997e-01  5 -0.038654 -0.045506
# bg-0:45         -0.044628  0.001173  9.999999e-01  5 -0.042212 -0.047044
# bg-0:30         -0.061769  0.002243  9.999998e-01  5 -0.057151 -0.066386
#
# [506 rows x 6 columns]

# %%
# Get the top 10 models based on the leaderboard
leaderboard = predictor.leaderboard(silent=True)
top_10_models = leaderboard['model'].head(10).tolist()

# Prepare the test data without the target column for prediction
test_data_no_target = test_data.drop(columns=[target], errors='ignore')

# Make predictions with each top model and save to individual submission files
for model in top_10_models:
    predictions = predictor.predict(test_data_no_target, model=model)
    submission = pd.DataFrame({'id': test_data['id'], target: predictions})
    submission_file = f"submission_{model}.csv"
    submission.to_csv(submission_file, index=False)
    print(f"Submission file saved for model {model} as {submission_file}.")
# Out:
# Submission file saved for model WeightedEnsemble_L3 as submission_WeightedEnsemble_L3.csv.
# Submission file saved for model LightGBMXT_BAG_L2 as submission_LightGBMXT_BAG_L2.csv.
# Submission file saved for model LightGBM_BAG_L2 as submission_LightGBM_BAG_L2.csv.
# Submission file saved for model CatBoost_BAG_L2 as submission_CatBoost_BAG_L2.csv.
# Submission file saved for model XGBoost_BAG_L2 as submission_XGBoost_BAG_L2.csv.
# Submission file saved for model RandomForestMSE_BAG_L2 as submission_RandomForestMSE_BAG_L2.csv.
# Submission file saved for model ExtraTreesMSE_BAG_L2 as submission_ExtraTreesMSE_BAG_L2.csv.
# Submission file saved for model WeightedEnsemble_L2 as submission_WeightedEnsemble_L2.csv.
# Submission file saved for model LightGBM_BAG_L1 as submission_LightGBM_BAG_L1.csv.
# Submission file saved for model LightGBMXT_BAG_L1 as submission_LightGBMXT_BAG_L1.csv.
